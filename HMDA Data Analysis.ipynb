# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np 
import os
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import math

from scipy import stats
from scipy.stats import boxcox
from scipy.stats import kstest
from scipy.stats import chi2

# %% [markdown]
# ### Set Path

# %%
path = 'C:\\Users\\padu\\Desktop\\HMDA'
os.chdir(path)

# %% [markdown]
# ### Read Data

# %%
HMDAData = pd.read_csv('HMDA.csv', low_memory=False)
HMDAData
# Out:
#         as_of_year respondent_id                                  agency_name  \
# 0             2017    48-1236121  Department of Housing and Urban Development
# 1             2017    54-1094297  Department of Housing and Urban Development
# 2             2017    37-1542226  Department of Housing and Urban Development
# 3             2017    0001189117         Consumer Financial Protection Bureau
# 4             2017    54-1094297  Department of Housing and Urban Development
# ...            ...           ...                                          ...
# 196981        2017    26-0595342  Department of Housing and Urban Development
# 196982        2017    0000216922                       Federal Reserve System
# 196983        2017    0542409990  Department of Housing and Urban Development
# 196984        2017    0002915461                       Federal Reserve System
# 196985        2017    0000216922                       Federal Reserve System
#
# ...

# %%
## Preview Columns
HMDAData .columns
# Out:
# Index(['as_of_year', 'respondent_id', 'agency_name', 'agency_abbr',
#        'agency_code', 'loan_type_name', 'loan_type', 'property_type_name',
#        'property_type', 'loan_purpose_name', 'loan_purpose',
#        'owner_occupancy_name', 'owner_occupancy', 'loan_amount_000s',
#        'preapproval_name', 'preapproval', 'action_taken_name', 'action_taken',
#        'msamd_name', 'msamd', 'state_name', 'state_abbr', 'state_code',
#        'county_name', 'county_code', 'census_tract_number',
#        'applicant_ethnicity_name', 'applicant_ethnicity',
#        'co_applicant_ethnicity_name', 'co_applicant_ethnicity',
#        'applicant_race_name_1', 'applicant_race_1', 'applicant_race_name_2',
#        'applicant_race_2', 'applicant_race_name_3', 'applicant_race_3',
#        'applicant_race_name_4', 'applicant_race_4', 'applicant_race_name_5',
#        'applicant_race_5', 'co_applicant_race_name_1', 'co_applicant_race_1',
#        'co_applicant_race_name_2', 'co_applicant_race_2',
# ...

# %%
HMDAData.head()
# Out:
#    as_of_year respondent_id                                  agency_name  \
# 0        2017    48-1236121  Department of Housing and Urban Development
# 1        2017    54-1094297  Department of Housing and Urban Development
# 2        2017    37-1542226  Department of Housing and Urban Development
# 3        2017    0001189117         Consumer Financial Protection Bureau
# 4        2017    54-1094297  Department of Housing and Urban Development
#
#   agency_abbr  agency_code loan_type_name  loan_type  \
# 0         HUD            7    FHA-insured          2
# 1         HUD            7   Conventional          1
# 2         HUD            7    FHA-insured          2
# 3        CFPB            9   Conventional          1
# 4         HUD            7   Conventional          1
#
#                                   property_type_name  property_type  \
# 0  One-to-four family dwelling (other than manufa...              1
# ...

# %%
HMDAData.groupby(['loan_purpose_name'])['action_taken'].sum()
# Out:
# loan_purpose_name
# Home improvement      5080
# Home purchase       130303
# Refinancing          61603
# Name: action_taken, dtype: int64

# %%
HMDAData['loan_purpose_name'].describe()
# Out:
# count            196986
# unique                3
# top       Home purchase
# freq             130303
# Name: loan_purpose_name, dtype: object

# %%
HMDAData.describe()
# Out:
#        as_of_year    agency_code      loan_type  property_type   loan_purpose  \
# count    196986.0  196986.000000  196986.000000       196986.0  196986.000000
# mean       2017.0       7.066995       1.528703            1.0       1.651244
# std           0.0       1.988245       0.855562            0.0       0.923355
# min        2017.0       1.000000       1.000000            1.0       1.000000
# 25%        2017.0       7.000000       1.000000            1.0       1.000000
# 50%        2017.0       7.000000       1.000000            1.0       1.000000
# 75%        2017.0       9.000000       2.000000            1.0       3.000000
# max        2017.0       9.000000       4.000000            1.0       3.000000
#
#        owner_occupancy  loan_amount_000s    preapproval  action_taken  \
# count         196986.0     196986.000000  196986.000000      196986.0
# mean               1.0        213.674302       2.709934           1.0
# ...

# %%
HMDAData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196986 entries, 0 to 196985
# Data columns (total 78 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   as_of_year                      196986 non-null  int64
#  1   respondent_id                   196986 non-null  object
#  2   agency_name                     196986 non-null  object
#  3   agency_abbr                     196986 non-null  object
#  4   agency_code                     196986 non-null  int64
#  5   loan_type_name                  196986 non-null  object
#  6   loan_type                       196986 non-null  int64
#  7   property_type_name              196986 non-null  object
#  8   property_type                   196986 non-null  int64
#  9   loan_purpose_name               196986 non-null  object
#  10  loan_purpose                    196986 non-null  int64
#  11  owner_occupancy_name            196986 non-null  object
# ...

# %%
HMDAData['hoepa_status_name'].value_counts()
# Out:
# Not a HOEPA loan    196964
# HOEPA loan              22
# Name: hoepa_status_name, dtype: int64

# %%
list(set(HMDAData['hoepa_status_name']))
# Out:
# ['Not a HOEPA loan', 'HOEPA loan']

# %%
pd.unique(HMDAData['hoepa_status_name'])
# Out:
# array(['Not a HOEPA loan', 'HOEPA loan'], dtype=object)
